# %% [markdown]
# # 2022/09/22 Gnuvil(BigData Study) 2주차_문제

# %% [markdown]
# - 실습 데이터 : titanic

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set()

# %% [markdown]
# ### Titanic Data

# %%
# 타이타닉 데이터 불러오기
df = sns.load_dataset('titanic')

# titanic 데이터 복사
titanic = df.copy()
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ###  **1. 데이터 확인**

# %%
# DataFrame 앞에서부터 10개의 행을 보는 코드작성(head()사용)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
# DataFrame 뒤에서부터 10개의 행을 보는 코드작성(tail()사용)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 881         0       3    male  33.0      0      0   7.8958        S   Third
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 883         0       2    male  28.0      0      0  10.5000        S  Second
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 881    man        True  NaN  Southampton    no   True
# ...

# %%
# 데이터 정보 확인. 변수명/결측값/타입(info()사용)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
# 데이터 통계값 확인(describe()사용)
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
# 결측값 확인(isnull()사용)
# Out:
#      survived  pclass    sex    age  sibsp  parch   fare  embarked  class  \
# 0       False   False  False  False  False  False  False     False  False
# 1       False   False  False  False  False  False  False     False  False
# 2       False   False  False  False  False  False  False     False  False
# 3       False   False  False  False  False  False  False     False  False
# 4       False   False  False  False  False  False  False     False  False
# ..        ...     ...    ...    ...    ...    ...    ...       ...    ...
# 886     False   False  False  False  False  False  False     False  False
# 887     False   False  False  False  False  False  False     False  False
# 888     False   False  False   True  False  False  False     False  False
# 889     False   False  False  False  False  False  False     False  False
# 890     False   False  False  False  False  False  False     False  False
#
#        who  adult_male   deck  embark_town  alive  alone
# ...

# %%
# column별 결측치 개수 확인(isnull().sum()사용)
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
# 'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town', 'alive', 'alone' 열 삭제
titanic_drop = 
titanic_drop
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare
# 0           0       3    male  22.0      1      0   7.2500
# 1           1       1  female  38.0      1      0  71.2833
# 2           1       3  female  26.0      0      0   7.9250
# 3           1       1  female  35.0      1      0  53.1000
# 4           0       3    male  35.0      0      0   8.0500
# ..        ...     ...     ...   ...    ...    ...      ...
# 886         0       2    male  27.0      0      0  13.0000
# 887         1       1  female  19.0      0      0  30.0000
# 888         0       3  female   NaN      1      2  23.4500
# 889         1       1    male  26.0      0      0  30.0000
# 890         0       3    male  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
# sex 컬럼에서 male은 0, female은 1로 값 대체(map함수 사용)
titanic_drop.sex =
titanic_drop
# Out:
#      survived  pclass  sex   age  sibsp  parch     fare
# 0           0       3    0  22.0      1      0   7.2500
# 1           1       1    1  38.0      1      0  71.2833
# 2           1       3    1  26.0      0      0   7.9250
# 3           1       1    1  35.0      1      0  53.1000
# 4           0       3    0  35.0      0      0   8.0500
# ..        ...     ...  ...   ...    ...    ...      ...
# 886         0       2    0  27.0      0      0  13.0000
# 887         1       1    1  19.0      0      0  30.0000
# 888         0       3    1   NaN      1      2  23.4500
# 889         1       1    0  26.0      0      0  30.0000
# 890         0       3    0  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
# age 컬럼에서 결측값을 중앙값으로 대체(fillna 사용)
titanic_drop.age = 
titanic_drop
# Out:
#      survived  pclass  sex   age  sibsp  parch     fare
# 0           0       3    0  22.0      1      0   7.2500
# 1           1       1    1  38.0      1      0  71.2833
# 2           1       3    1  26.0      0      0   7.9250
# 3           1       1    1  35.0      1      0  53.1000
# 4           0       3    0  35.0      0      0   8.0500
# ..        ...     ...  ...   ...    ...    ...      ...
# 886         0       2    0  27.0      0      0  13.0000
# 887         1       1    1  19.0      0      0  30.0000
# 888         0       3    1  28.0      1      2  23.4500
# 889         1       1    0  26.0      0      0  30.0000
# 890         0       3    0  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
# feature과 target 설정(survived를 종속변수로, 그 외 feature을 독립변수로 사용)
feature_cols = titanic_drop.columns['알맞게 인덱싱 하시오.']

X = titanic_drop['알맞은 변수 기입']
y = titanic_drop.알맞은 변수 기입

# %%
# train_test 분리 80:20(random_state=42 사용)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test =

# %%
# X_train, X_test, y_train, y_test 데이터 확인(shape사용)
print()
print()
# Out:
# (712, 6) (179, 6)
# (712,) (179,)

# %%
# X_train과 X_test 표준화
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform('알맞은 변수 기입')
X_test = scaler.transform('알맞은 변수 기입')

# %%
# knn 알고리즘
from sklearn.neighbors import KNeighborsClassifier
kn = KNeighborsClassifier()

kn.fit('알맞은 변수 기입')
# Out:
# KNeighborsClassifier()

# %%
y_predict = kn.predict('알맞은 변수 기입')
 
print('KNN Accuracy: ', )
# Out:
# KNN Accuracy:  0.7877094972067039

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.83      0.82       105
#            1       0.75      0.73      0.74        74
#
#     accuracy                           0.79       179
#    macro avg       0.78      0.78      0.78       179
# weighted avg       0.79      0.79      0.79       179

# %% [markdown]
# ### 문제) knn 알고리즘에서 k의 값으로 짝수를 기피하는 경향이 있다. 이유는?

# %% [markdown]
# ### 문제) 사이킷-런에서 StandardScaler()은 평균과 표준편차를 사용한 스케일링 기법이다. 그러면 MinMaxScaler()은 어떤 스케일링 기법인가?
